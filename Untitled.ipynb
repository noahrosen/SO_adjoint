# %%
import numpy as np
import xarray as xr
import xmitgcm as xm
import ecco_v4_py as ecco

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
path = '/glade/campaign/work/dafydd/ECCOv4r4_data'
ds = xr.open_dataset(f'{path}/ECCO-GRID.nc')

# %%
ds.Depth.plot(x='XC',y='YC',col='tile',col_wrap=3,robust=True,subplot_kws=dict(projection=ccrs.PlateCarree()))
