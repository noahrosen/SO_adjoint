# %%
import xarray as xr

# %%
theta = xr.open_dataset('/glade/work/noahrose/RG_clim/RG_ArgoClim_Temperature_2019.nc',decode_times=False)
salt = xr.open_dataset('/glade/work/noahrose/RG_clim/RG_ArgoClim_Salinity_2019.nc',decode_times=False)

# %%
theta.ARGO_TEMPERATURE_ANOMALY[0,0,:,:].plot()
